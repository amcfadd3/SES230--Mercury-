# %% [markdown]
# # SES230 Group Mercury Final Report
#
# This notebook analyzes earthquake counts by California rock type using a spatial join between earthquake point data and rock type polygon data.

# %% [markdown]
# ## Setup
#
# Raw shapefile components should be placed in `data/raw/`. The expected shapefiles are `California_Rock_Types.shp` and `CA_EQ_Shallow.shp`.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
sys.path.append(str(PROJECT_ROOT / "code"))

from analysis import run_analysis

# %% [markdown]
# ## Earthquake Count by Rock Type

# %%
summary = run_analysis()
summary

# %% [markdown]
# ## Notes for Final Submission
#
# Add written interpretation, source citations, and any final figures here before submitting.
